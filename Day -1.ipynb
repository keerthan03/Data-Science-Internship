# %%
import cv2
import numpy as np

# %%
image = cv2.imread('img2.jpeg')

# %%
print(image.shape)
# Out:
# (30, 30, 3)

# %%
print(image.dtype)
# Out:
# uint8

# %%
image
# Out:
# array([[[  0,   0, 254],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [255,  12,   0],
#         [255,  12,   0],
#         [255,  12,   0]],
#
#        [[  0,   0, 254],
#         [  0,   1, 253],
#         [  0,   1, 253],
#         ...,
#         [255,  12,   0],
#         [255,  13,   0],
#         [254,  12,   0]],
#
#        [[  0,   0, 254],
#         [  0,   1, 253],
#         [  0,   1, 253],
#         ...,
#         [254,  12,   0],
#         [255,  12,   0],
#         [254,  12,   0]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [  0, 255,  41],
#         [  0, 255,  41],
#         [  0, 255,  41]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [  0, 255,  41],
#         [  0, 255,  41],
#         [  0, 255,  41]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
image[0][16:25]
# Out:
# array([[190,  15,  82],
#        [204,   3,  37],
#        [243,  10,   8],
#        [255,  13,   0],
#        [255,  13,   0],
#        [252,  11,   2],
#        [254,  11,   2],
#        [255,  12,   0],
#        [255,  12,   0]], dtype=uint8)

# %%
image[0][10:20]
# Out:
# array([[  0,   2, 251],
#        [  0,   0, 254],
#        [  0,   1, 254],
#        [  7,   7, 239],
#        [ 26,  28, 190],
#        [  0,   0,  73],
#        [190,  15,  82],
#        [204,   3,  37],
#        [243,  10,   8],
#        [255,  13,   0]], dtype=uint8)

# %%
for i in range(30):
    for j in range(30):
        print(image[i][j])
    print()
# Out:
# [  0   0 254]
# [  0   0 254]
# [  0   0 254]
# [  0   0 254]
# [  0   0 254]
# [  2   0 253]
# [  2   0 254]
# [  0   0 254]
# [  0   0 254]
# [  0   2 251]
# [  0   2 251]
# [  0   0 254]
# [  0   1 254]
# [  7   7 239]
# [ 26  28 190]
# [ 0  0 73]
# [190  15  82]
# [204   3  37]
# [243  10   8]
# [255  13   0]
# [255  13   0]
# [252  11   2]
# [254  11   2]
# [255  12   0]
# [255  12   0]
# [255  12   0]
# [255  12   0]
# [255  12   0]
# [255  12   0]
# [255  12   0]
#
# [  0   0 254]
# [  0   1 253]
# [  0   1 253]
# [  0   0 254]
# [  0   0 254]
# [  2   0 253]
# [  2   1 251]
# [  0   0 254]
# [  0   0 254]
# [  2   1 251]
# [  2   2 250]
# [  0   0 254]
# [  0   1 254]
# [  7   7 239]
# [ 26  28 190]
# [ 0  0 73]
# [190  15  82]
# [203   3  37]
# [242  10   8]
# [255  13   0]
# [255  12   0]
# [252  11   2]
# [252  12   1]
# [255  13   0]
# [255  13   0]
# [254  12   1]
# [254  12   1]
# [255  12   0]
# [255  13   0]
# [254  12   0]
#
# [  0   0 254]
# [  0   1 253]
# ...
