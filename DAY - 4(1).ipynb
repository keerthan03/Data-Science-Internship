# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Fraud.csv')
#print(df.describe())
newdf = df.iloc[:100]

print(pd.mean(df['amount'].mean()))
plt.plot(range(len(df)),df['amount'],'o',label="numbers vs amount")
plt.show()

# print(newdf.describe())
# Out:
# 171508.16239106958
