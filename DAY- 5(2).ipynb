# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/Fraud.csv')
print(data)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1          1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2          1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3          1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4          1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 233387    14   PAYMENT   22222.69  C1925997510        11637.0            0.00
# 233388    14  CASH_OUT  301902.82  C1773769722          724.0            0.00
# 233389    14  CASH_OUT  256081.64  C1492972627        70186.0            0.00
# 233390    14   PAYMENT   15925.87  C1237286617            0.0            0.00
# 233391    14  CASH_OUT  154410.27   C787622794           11.0             NaN
#
# ...

# %%
correlation=data.corr()
print(correlation)
# Out:
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.036637      -0.009606       -0.008881
# amount          0.036637  1.000000      -0.019674       -0.023664
# oldbalanceOrg  -0.009606 -0.019674       1.000000        0.998951
# newbalanceOrig -0.008881 -0.023664       0.998951        1.000000
# oldbalanceDest  0.027740  0.216592       0.094663        0.096280
# newbalanceDest  0.007219  0.337897       0.063587        0.062663
# isFraud        -0.035542  0.046325      -0.001220       -0.008011
# isFlaggedFraud       NaN       NaN            NaN             NaN
#
#                 oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# step                  0.027740        0.007219 -0.035542             NaN
# amount                0.216592        0.337897  0.046325             NaN
# oldbalanceOrg         0.094663        0.063587 -0.001220             NaN
# newbalanceOrig        0.096280        0.062663 -0.008011             NaN
# ...

# %%
data.corr()
# Out:
# <ipython-input-24-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                       step    amount  oldbalanceOrg  newbalanceOrig  \
# step              1.000000  0.036637      -0.009606       -0.008881
# amount            0.036637  1.000000      -0.019674       -0.023664
# oldbalanceOrg    -0.009606 -0.019674       1.000000        0.998951
# newbalanceOrig   -0.008881 -0.023664       0.998951        1.000000
# oldbalanceDest    0.027740  0.216592       0.094663        0.096280
# newbalanceDest    0.007219  0.337897       0.063587        0.062663
# isFraud          -0.035542  0.046325      -0.001220       -0.008011
# isFlaggedFraud         NaN       NaN            NaN             NaN
# Category-encoded -0.080339  0.091954      -0.351552       -0.365981
#
# ...

# %%
data.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  233392.000000  2.333920e+05   2.333920e+05    2.333910e+05
# mean       10.544663  1.802717e+05   8.749082e+05    8.930842e+05
# std         2.294623  3.211026e+05   2.785765e+06    2.822999e+06
# min         1.000000  3.000000e-01   0.000000e+00    0.000000e+00
# 25%         9.000000  1.237020e+04   0.000000e+00    0.000000e+00
# 50%        11.000000  7.252839e+04   1.880450e+04    0.000000e+00
# 75%        12.000000  2.313674e+05   1.849885e+05    2.232119e+05
# max        14.000000  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest        isFraud  isFlaggedFraud  \
# count    2.333910e+05    2.333910e+05  233391.000000        233391.0
# mean     9.560490e+05    1.192962e+06       0.000673             0.0
# std      2.369945e+06    2.627492e+06       0.025928             0.0
# min      0.000000e+00    0.000000e+00       0.000000             0.0
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Correlation matrix")
plt.show()

# %%
#to get number of rows in data
rows=data.shape[0]
print("The number of rows in  data is :",rows)
# Out:
# The number of rows in  data is : 233392

# %%
#to get the number of column
col=data.shape[1]
print("The number of columns in data is:",col)
# Out:
# The number of columns in data is: 11

# %%
#filtering the data
filter=data[data['isFraud']==1]
print(filter)
print(filter.shape[0])
# Out:
#         step      type      amount     nameOrig  oldbalanceOrg  \
# 2          1  TRANSFER      181.00  C1305486145         181.00
# 3          1  CASH_OUT      181.00   C840083671         181.00
# 251        1  TRANSFER     2806.00  C1420196421        2806.00
# 252        1  CASH_OUT     2806.00  C2101527076        2806.00
# 680        1  TRANSFER    20128.00   C137533655       20128.00
# ...      ...       ...         ...          ...            ...
# 217320    13  TRANSFER  6188514.81   C135832352     6188514.81
# 217321    13  CASH_OUT  6188514.81   C686187434     6188514.81
# 217978    13  TRANSFER   123194.95  C2143112877       79466.45
# 222997    14  TRANSFER  2093951.47  C1374377088     2093951.47
# 222998    14  CASH_OUT  2093951.47  C1440901488     2093951.47
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                  0.0   C553264065            0.00            0.00      1.0
# ...

# %%
filter2=data[(data['isFraud']==0) & (data['nameDest']=='C985934102')]
print(filter2)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 114        1  CASH_OUT   11648.50   C781091365           0.00            0.00
# 188        1  CASH_OUT  191702.06  C2052457859           0.00            0.00
# 194        1  CASH_OUT   88834.86   C938463537           0.00            0.00
# 210        1  CASH_OUT  503333.79  C1640612861           0.00            0.00
# 285        1  CASH_OUT  202624.59   C452364286           0.00            0.00
# ...      ...       ...        ...          ...            ...             ...
# 129429    11  CASH_OUT  101561.84  C1718441273       39685.00            0.00
# 165796    12   CASH_IN  422567.02   C824636829     7411935.74      7834502.77
# 183648    13  CASH_OUT  275717.78  C1289295238           0.00            0.00
# 184484    13  CASH_OUT  511639.39  C1668848151           0.00            0.00
# 188727    13  CASH_OUT  211158.10   C318286601           0.00            0.00
#
# ...

# %%
#filter using query method
filter3=data.query('newbalanceOrig > 20000 and newbalanceDest > 100000')
print(filter3)
# Out:
#         step     type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 260        1    DEBIT    1393.46    C79290250      100068.00        98674.54
# 300        1    DEBIT    3428.95  C1317375498      147798.00       144369.05
# 335        1    DEBIT    4565.14   C201274566       30265.00        25699.86
# 366        1    DEBIT     996.00  C1839206329       46132.00        45136.00
# 390        1  CASH_IN  228451.89  C1614133563      143236.26       371688.15
# ...      ...      ...        ...          ...            ...             ...
# 233305    14  CASH_IN   60819.41  C1571933962      183628.00       244447.41
# 233308    14  CASH_IN  189460.12  C1663200506       21502.00       210962.12
# 233324    14  CASH_IN  305391.55  C1379560858       21297.00       326688.55
# 233352    14  CASH_IN  296595.52  C1032801563         739.00       297334.52
# 233382    14  CASH_IN   73712.93   C231825492       24479.00        98191.93
#
# ...

# %%
#filter using isin method
filter4=data[data['nameDest'].isin(['C985934102','M1176932104'])]
print(filter4)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 8          1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 114        1  CASH_OUT   11648.50   C781091365           0.00            0.00
# 188        1  CASH_OUT  191702.06  C2052457859           0.00            0.00
# 194        1  CASH_OUT   88834.86   C938463537           0.00            0.00
# 210        1  CASH_OUT  503333.79  C1640612861           0.00            0.00
# ...      ...       ...        ...          ...            ...             ...
# 129429    11  CASH_OUT  101561.84  C1718441273       39685.00            0.00
# 165796    12   CASH_IN  422567.02   C824636829     7411935.74      7834502.77
# 183648    13  CASH_OUT  275717.78  C1289295238           0.00            0.00
# 184484    13  CASH_OUT  511639.39  C1668848151           0.00            0.00
# 188727    13  CASH_OUT  211158.10   C318286601           0.00            0.00
#
# ...

# %%
data['Category-encoded']=data['type'].astype('category').cat.codes
print(data)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1          1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2          1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3          1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4          1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 233387    14   PAYMENT   22222.69  C1925997510        11637.0            0.00
# 233388    14  CASH_OUT  301902.82  C1773769722          724.0            0.00
# 233389    14  CASH_OUT  256081.64  C1492972627        70186.0            0.00
# 233390    14   PAYMENT   15925.87  C1237286617            0.0            0.00
# 233391    14  CASH_OUT  154410.27   C787622794           11.0             NaN
#
# ...

# %%
df=pd.DataFrame(data)
df=df[['step','type','Category-encoded','amount','nameOrig','oldbalanceOrg','newbalanceOrig','nameDest','oldbalanceDest','newbalanceDest','isFraud','isFlaggedFraud']]
print(df)
# Out:
#         step      type  Category-encoded     amount     nameOrig  \
# 0          1   PAYMENT                 3    9839.64  C1231006815
# 1          1   PAYMENT                 3    1864.28  C1666544295
# 2          1  TRANSFER                 4     181.00  C1305486145
# 3          1  CASH_OUT                 1     181.00   C840083671
# 4          1   PAYMENT                 3   11668.14  C2048537720
# ...      ...       ...               ...        ...          ...
# 233387    14   PAYMENT                 3   22222.69  C1925997510
# 233388    14  CASH_OUT                 1  301902.82  C1773769722
# 233389    14  CASH_OUT                 1  256081.64  C1492972627
# 233390    14   PAYMENT                 3   15925.87  C1237286617
# 233391    14  CASH_OUT                 1  154410.27   C787622794
#
#         oldbalanceOrg  newbalanceOrig     nameDest  oldbalanceDest  \
# 0            170136.0       160296.36  M1979787155            0.00
# ...
