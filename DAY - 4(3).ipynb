# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/Fraud.csv')
print(data)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1          1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2          1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3          1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4          1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 219760    14   PAYMENT     591.50  C1443113739      104879.68       104288.18
# 219761    14   PAYMENT   14839.24   C554257502      104288.18        89448.94
# 219762    14   CASH_IN  144258.67   C865880896      298512.00       442770.67
# 219763    14  CASH_OUT  348453.47  C1483305396       11894.00            0.00
# 219764    14   PAYMENT   38981.58   C862563675          11.00             NaN
#
# ...

# %%
newdf=data.head(50)
newdf
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1      1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2      1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3      1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4      1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# 5      1   PAYMENT    7817.71    C90045638       53860.00        46042.29
# 6      1   PAYMENT    7107.77   C154988899      183195.00       176087.23
# 7      1   PAYMENT    7861.64  C1912850431      176087.23       168225.59
# 8      1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 9      1     DEBIT    5337.77   C712410124       41720.00        36382.23
# 10     1     DEBIT    9644.94  C1900366749        4465.00            0.00
# 11     1   PAYMENT    3099.97   C249177573       20771.00        17671.03
# ...

# %%
unique_val=newdf['nameDest'].unique()
unique_val
# Out:
# array(['M1979787155', 'M2044282225', 'C553264065', 'C38997010',
#        'M1230701703', 'M573487274', 'M408069119', 'M633326333',
#        'M1176932104', 'C195600860', 'C997608398', 'M2096539129',
#        'M972865270', 'M801569151', 'M1635378213', 'C476402209',
#        'M1731217984', 'M1877062907', 'M473053293', 'C1100439041',
#        'M1344519051', 'C1973538135', 'C515132998', 'M1404932042',
#        'C932583850', 'M1558079303', 'M58488213', 'M295304806',
#        'M33419717', 'M1940055334', 'M335107734', 'M1757317128',
#        'M1804441305', 'M1971783162', 'M151442075', 'M70695990',
#        'M1615617512', 'M107994825', 'M1426725223', 'M1384454980',
#        'M1569435561', 'C1297685781', 'C1509514333', 'M267814113',
#        'M1593224710', 'M1849015357', 'M2008106788', 'C824009085',
#        'C248609774', 'M490391704'], dtype=object)

# %%
duplicate_val=data.duplicated(subset='nameDest').sum()
print(duplicate_val)

dup=data[data.duplicated(subset='nameDest',keep=False)]
value_counts=dup['nameDest'].value_counts()
repeat=value_counts.idxmax()
repeatcnt=value_counts.max()

print("Most repeated destination address:",repeat)
print("Its occurance:",repeatcnt)
# Out:
# 116852
# Most repeated destination address: C985934102
# Its occurance: 84

# %%
newdf['amount']=newdf['amount'].astype('category')
print(newdf)
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1      1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2      1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3      1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4      1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# 5      1   PAYMENT    7817.71    C90045638       53860.00        46042.29
# 6      1   PAYMENT    7107.77   C154988899      183195.00       176087.23
# 7      1   PAYMENT    7861.64  C1912850431      176087.23       168225.59
# 8      1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 9      1     DEBIT    5337.77   C712410124       41720.00        36382.23
# 10     1     DEBIT    9644.94  C1900366749        4465.00            0.00
# 11     1   PAYMENT    3099.97   C249177573       20771.00        17671.03
# ...

# %%
print(newdf['amount'].cat.categories)
print(newdf['amount'].cat.ordered)
# Out:
# Float64Index([    181.0,    671.64,   1065.41,   1157.86,   1373.43,   1563.82,
#                 1684.81,   1864.28,   2204.04,   2560.74,   2791.42,   3099.97,
#                 3295.19,   3448.92,   3876.41,   4024.36,   4098.78,   4206.84,
#                 5031.22,   5086.48,   5281.48,   5307.88,   5337.77,   5346.89,
#                 5758.59,   5885.56,   6061.13,   7107.77,   7413.54,   7817.71,
#                 7823.46,   7861.64,   8009.09,   8603.42,   8901.99,   9302.79,
#                 9478.39,   9644.94,   9839.64,   9920.52,  11633.76,  11668.14,
#                13875.98,  24213.67,   56953.9, 110414.71,  215310.3, 229133.94,
#               311685.89],
#              dtype='float64')
# False

# %%
newdf['amount']=newdf['amount'].cat.add_categories([8974,56465])
print(newdf)
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1      1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2      1  TRANSFER      181.0  C1305486145         181.00            0.00
# 3      1  CASH_OUT      181.0   C840083671         181.00            0.00
# 4      1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# 5      1   PAYMENT    7817.71    C90045638       53860.00        46042.29
# 6      1   PAYMENT    7107.77   C154988899      183195.00       176087.23
# 7      1   PAYMENT    7861.64  C1912850431      176087.23       168225.59
# 8      1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 9      1     DEBIT    5337.77   C712410124       41720.00        36382.23
# 10     1     DEBIT    9644.94  C1900366749        4465.00            0.00
# 11     1   PAYMENT    3099.97   C249177573       20771.00        17671.03
# ...

# %%
data .isna()
# Out:
#          step   type  amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       False  False   False     False          False           False
# 1       False  False   False     False          False           False
# 2       False  False   False     False          False           False
# 3       False  False   False     False          False           False
# 4       False  False   False     False          False           False
# ...       ...    ...     ...       ...            ...             ...
# 219760  False  False   False     False          False           False
# 219761  False  False   False     False          False           False
# 219762  False  False   False     False          False           False
# 219763  False  False   False     False          False           False
# 219764  False  False   False     False          False            True
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...
