# %%
import pandas as pd
import numpy as np

# Creation of DataFrame
data = pd.read_csv('/content/Fraud.csv')
df = pd.DataFrame(data)

# Adding a new column
df['DerivedColumn'] = df['amount'] * 2

print(df)
print()

# Removing a column
df.drop('DerivedColumn', axis=1, inplace=True)

print(df)
print()

newdf=df.head(1000)
print(df)
print()

# Iterating through DataFrame
print("Iterating through DataFrame:")
for index, row in newdf.iterrows():
    print(f'Index: {index}, Column2: {row["amount"]}, NewColumn: {row["nameDest"]}')

# Indexing DataFrame
df.set_index('type', inplace=True)

# Selecting specific columns (for example, 'Column1')
selected_columns = df['amount']
print(selected_columns)
print()

# Handling missing data in DataFrame
# Filling missing values with a specific value (e.g., 0)
df.fillna(value=0, inplace=True)

print("\nDataFrame after handling missing data:")
print(df)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.64  C1231006815       170136.0
# 1           1   PAYMENT    1864.28  C1666544295        21249.0
# 2           1  TRANSFER     181.00  C1305486145          181.0
# 3           1  CASH_OUT     181.00   C840083671          181.0
# 4           1   PAYMENT   11668.14  C2048537720        41554.0
# ...       ...       ...        ...          ...            ...
# 1361084   138  CASH_OUT   39131.45  C1753002759            0.0
# 1361085   138  CASH_OUT  208009.21   C917518550            0.0
# 1361086   138  CASH_OUT  408972.53   C628209371            0.0
# 1361087   138  CASH_OUT  177495.04  C1791205795            0.0
# 1361088   138  CASH_OUT  132198.31          NaN            NaN
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00      0.0
# ...
