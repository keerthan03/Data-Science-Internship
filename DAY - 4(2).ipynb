# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Fraud.csv',index_col='type')

df
df.columns
df.columns=[['steps','amounts','name_orig','old_bal_org','new_bal_org','nam_dest','old_bal_dest','new_bal_dest','fraud','fraud_flag']]

# %%
newdf=df.drop(['steps','fraud_flag','name_orig','nam_dest'],axis=1)
newdf
# Out:
# <ipython-input-63-fde2f5ae53a1>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   newdf=df.drop(['steps','fraud_flag','name_orig','nam_dest'],axis=1)
#             amounts old_bal_org new_bal_org old_bal_dest new_bal_dest fraud
# type
# PAYMENT     9839.64    170136.0   160296.36         0.00         0.00     0
# PAYMENT     1864.28     21249.0    19384.72         0.00         0.00     0
# TRANSFER     181.00       181.0        0.00         0.00         0.00     1
# CASH_OUT     181.00       181.0        0.00     21182.00         0.00     1
# PAYMENT    11668.14     41554.0    29885.86         0.00         0.00     0
# ...             ...         ...         ...          ...          ...   ...
# PAYMENT     2036.34     10922.0     8885.66         0.00         0.00     0
# CASH_OUT  130901.01     14370.0        0.00    160949.16    291850.17     0
# ...

# %%
newdf.loc['PAYMENT','amounts']
# Out:
#           amounts
# type
# PAYMENT   9839.64
# PAYMENT   1864.28
# PAYMENT  11668.14
# PAYMENT   7817.71
# PAYMENT   7107.77
# ...           ...
# PAYMENT  19314.06
# PAYMENT   6481.58
# PAYMENT   2392.29
# PAYMENT  56189.51
# PAYMENT   2036.34
#
# [1398206 rows x 1 columns]

# %%
df.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  545326.000000  5.453260e+05   5.453260e+05    5.453260e+05
# mean       14.435589  1.628503e+05   9.032147e+05    9.229918e+05
# std         3.983863  2.676955e+05   3.000850e+06    3.037953e+06
# min         1.000000  1.000000e-01   0.000000e+00    0.000000e+00
# 25%        11.000000  1.289251e+04   0.000000e+00    0.000000e+00
# 50%        15.000000  7.882464e+04   1.828950e+04    0.000000e+00
# 75%        18.000000  2.177040e+05   1.634999e+05    2.027670e+05
# max        21.000000  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest        isFraud  isFlaggedFraud
# count    5.453250e+05    5.453250e+05  545325.000000        545325.0
# mean     9.793806e+05    1.150675e+06       0.000440             0.0
# std      2.327064e+06    2.492859e+06       0.020974             0.0
# min      0.000000e+00    0.000000e+00       0.000000             0.0
# ...

# %%
df.median()
# Out:
# <ipython-input-29-2adaf1c72778>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# step                  15.000
# amount             78824.645
# oldbalanceOrg      18289.500
# newbalanceOrig         0.000
# oldbalanceDest    119661.250
# newbalanceDest    216855.170
# isFraud                0.000
# isFlaggedFraud         0.000
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-26-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# step              1.587116e+01
# amount            7.166090e+10
# oldbalanceOrg     9.005099e+12
# newbalanceOrig    9.229161e+12
# oldbalanceDest    5.415227e+12
# newbalanceDest    6.214347e+12
# isFraud           4.399116e-04
# isFlaggedFraud    0.000000e+00
# dtype: float64

# %%
df.min()
# Out:
# step                        1
# type                  CASH_IN
# amount                    0.1
# nameOrig          C1000008582
# oldbalanceOrg             0.0
# newbalanceOrig            0.0
# nameDest          C1000015936
# oldbalanceDest            0.0
# newbalanceDest            0.0
# isFraud                   0.0
# isFlaggedFraud            0.0
# dtype: object

# %%
df.max()
# Out:
# step                       21
# type                 TRANSFER
# amount             10000000.0
# nameOrig           C999998175
# oldbalanceOrg     38939424.03
# newbalanceOrig    38946233.02
# nameDest           M999996397
# oldbalanceDest    41482697.12
# newbalanceDest    41482697.12
# isFraud                   1.0
# isFlaggedFraud            0.0
# dtype: object

# %%
num_col=df.select_dtypes(include=['number'])
range=num_col.max()-num_col.min()
print(range)
# Out:
# step                    20.00
# amount             9999999.90
# oldbalanceOrg     38939424.03
# newbalanceOrig    38946233.02
# oldbalanceDest    41482697.12
# newbalanceDest    41482697.12
# isFraud                  1.00
# isFlaggedFraud           0.00
# dtype: float64

# %%
d=df.dtypes
d
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud           float64
# isFlaggedFraud    float64
# dtype: object

# %%
null_there=df.isna().any(axis=1)
df[null_there]
# Out:
#         step      type    amount    nameOrig  oldbalanceOrg  newbalanceOrig  \
# 545325    21  TRANSFER  283797.8  C410918453        10298.0             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 545325  C8588568             NaN             NaN      NaN             NaN
